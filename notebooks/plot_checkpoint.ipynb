# %%
import sys
sys.path.append('..')
print(sys.path)
# Out:
# ['/home/jered/Documents/Projects/SummarizationCleanup2/venv/lib/python36.zip', '/home/jered/Documents/Projects/SummarizationCleanup2/venv/lib/python3.6', '/home/jered/Documents/Projects/SummarizationCleanup2/venv/lib/python3.6/lib-dynload', '/usr/lib/python3.6', '', '/home/jered/Documents/Projects/SummarizationCleanup2/venv/lib/python3.6/site-packages', '/home/jered/Documents/Projects/SummarizationCleanup2/venv/lib/python3.6/site-packages/IPython/extensions', '/home/jered/.ipython', '..']

# %%
from pytorch_helper import plot_checkpoint

# %%
ax_losses, ax_errors = plot_checkpoint("../Checkpoints/LSTM/checkpoint", figure_name='plot', show=False, average_over=50)
# ax_losses.set_ylim([2.5,6])
# ax_losses.set_xlim([-2000,110000])

# ax_losses, ax_errors = plot_checkpoint("Checkpoints/Transformer/checkpoint", figure_name='plot', show=False, average_over=50)
# ax_losses.set_ylim([2.5,6])
# ax_losses.set_xlim([-2000,110000])
