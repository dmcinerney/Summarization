# %%
from pytorch_helper import plot_checkpoint

# %%
ax_losses, ax_errors = plot_checkpoint("checkpoints/LSTMCheckpoints5/checkpoint", figure_name='plot', show=False, average_over=50)
ax_losses.set_ylim([2.5,8])
ax_losses.set_xlim([-200,210000])
ax_losses, ax_errors = plot_checkpoint("checkpoints/LSTMCheckpoints4/checkpoint", figure_name='plot', show=False, average_over=50)
ax_losses.set_ylim([2.5,8])
ax_losses.set_xlim([-200,210000])
# Out:
# (-200, 210000)
