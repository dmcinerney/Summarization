# %%
from pytorch_helper import plot_checkpoint

# %%
ax_losses, ax_errors = plot_checkpoint("EMNLP/TransformerSeq2SeqAttn3/checkpoint", figure_name='plot', show=False, average_over=50)
# ax_losses.set_ylim([2.3,6])
# ax_losses.set_xlim([-2000,110000])

# ax_losses, ax_errors = plot_checkpoint("EMNLP/TransformerHierarchical/checkpoint", figure_name='plot', show=False, average_over=50)
# ax_losses.set_ylim([2.3,6])
# ax_losses.set_xlim([-2000,110000])
