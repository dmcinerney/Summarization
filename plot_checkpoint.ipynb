# %%
from pytorch_helper import plot_checkpoint

# %%
ax_losses, ax_errors = plot_checkpoint("checkpoint", figure_name='plot', show=False, average_over=1)
ax_losses.set_ylim([0,10])
ax_losses.set_xlim([-200,4000])
# ax_losses, ax_errors = plot_checkpoint("checkpoint1", figure_name='plot', show=False, average_over=10)
# ax_losses.set_ylim([0,10])
# ax_losses.set_xlim([-2000,50000])
# Out:
# (-200, 4000)
