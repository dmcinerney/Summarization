# %%
from pytorch_helper import plot_checkpoint

# %%
ax_losses, ax_errors = plot_checkpoint("checkpoint", figure_name='plot', show=False, average_over=5)
# ax_losses.set_ylim([2.2,3.8])
# ax_losses.set_xlim([0,500000])
ax_losses.set_ylim([6,7.5])
ax_losses.set_xlim([0,1000])
ax_losses, ax_errors = plot_checkpoint("checkpoint2", figure_name='plot', show=False, average_over=5)
# ax_losses.set_ylim([2.2,3.8])
# ax_losses.set_xlim([0,500000])
ax_losses.set_ylim([6,7.5])
ax_losses.set_xlim([0,1000])
# Out:
# (0, 1000)
