# %%
from pytorch_helper import plot_checkpoint

# %%
ax_losses, ax_errors = plot_checkpoint("checkpoints/TransformerOOM/checkpoint", figure_name='plot', show=False, average_over=10)
ax_losses.set_ylim([2.5,8])
ax_losses.set_xlim([-2000,60000])
# Out:
# (-2000, 60000)
